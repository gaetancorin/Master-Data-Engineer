# %% [markdown]
# # 📝 Exercice 1

# %% [markdown]
# Supposons que nous soyons intéressés par la prédiction de l'espèce des pingouins à partir de deux de leurs mesures corporelles : la longueur du culmen et la profondeur du culmen. Tout d'abord, nous voulons faire une exploration des données pour avoir une idée de ces données.
#
# Quelles sont les caractéristiques (indépendantes) ? Quelle est la caractéristique cible (dépendante) ?

# %% [markdown]
# Les données sont situées dans `../datasets/penguins_classification.csv`, chargez-les avec
# `pandas` dans un `DataFrame`.

# %%
import pandas as pd

df = pd.read_csv('../datasets/penguins_classification.csv')
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm) Species
# 0                39.1               18.7  Adelie
# 1                39.5               17.4  Adelie
# 2                40.3               18.0  Adelie
# 3                36.7               19.3  Adelie
# 4                39.3               20.6  Adelie

# %%
df.columns
# les caractéristiques indépendantes sont Culmen Length (mm) et Culmen Depth (mm).
# La caractéristique cible cible est Species
# Out:
# Index(['Culmen Length (mm)', 'Culmen Depth (mm)', 'Species'], dtype='object')

# %% [markdown]
# Afficher quelques points de données.
#
# Combien de caractéristiques sont numériques ? Combien de caractéristiques sont catégoriques ?

# %%
for column in df:
    print(df[column].dtype)
"Il y a 2 caracteristiques float et 1 caractéristique objet"
# Out:
# float64
# float64
# object
# 'Il y a 2 caracteristiques float et 1 caractéristique objet'

# %% [markdown]
# Quelles sont les différentes espèces de manchots disponibles dans l'ensemble de données et combien de points de chaque espèce sont disponibles ?
# Astuce : sélectionnez la bonne colonne et utilisez la fonction
# [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# méthode.

# %%
df['Species'].value_counts()
# Out:
# Species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# Afficher les histogrammes pour les caractéristiques numériques

# %%
import matplotlib.pyplot as plt
plt.hist(df['Culmen Length (mm)'], bins=10, color='skyblue', edgecolor='black')
# Out:
# (array([ 9., 40., 57., 48., 49., 55., 61., 16.,  5.,  2.]),
#  array([32.1 , 34.85, 37.6 , 40.35, 43.1 , 45.85, 48.6 , 51.35, 54.1 ,
#         56.85, 59.6 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Culmen Depth (mm)'], bins=10, color='red', edgecolor='black')
# Out:
# (array([21., 35., 32., 34., 44., 55., 56., 39., 16., 10.]),
#  array([13.1 , 13.94, 14.78, 15.62, 16.46, 17.3 , 18.14, 18.98, 19.82,
#         20.66, 21.5 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Afficher la distribution des caractéristiques pour chaque classe. Astuce : utilisez
# [`seaborn.pairplot`](https://seaborn.pydata.org/generated/seaborn.pairplot.html)

# %%
import seaborn as sns
sns.pairplot(df, hue='Species')
# Out:
# C:\Users\gaeta\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# En analysant ces distributions, quels sont les pinguoins, pensez-vous, qui sont relativement difficiles à classer en utilisant uniquement la "profondeur du culmen" ou la "longueur du culmen" ?

# %%
# En utilisant uniquement la profondeur du culmen(Culmen Depth (mm)), il est difficile de classer les "Adelie" et "Chinstrap"
# car ils ont environ les mêmes valeurs.

# En utilisant uniquement la longueur du culmen (Culmen Length (mm)), il est difficile de classer les "Gentoo" et "Chinstrap"
# car ils ont environ les mêmes valeurs.

# %%
# Écrivez votre réponse ici.
