# %% [markdown]
# # Exercice 1

# %%
# EXERCICE 1:
import itertools
from scipy.spatial import distance
import pandas as pd
import numpy as np

dataframes = ["./A.csv", "./B.csv", "./C.csv"]

# distance euclidienne
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b)**2))

csv_A = pd.read_csv(dataframes[0], index_col = 0).select_dtypes(include='float64')
csv_B = pd.read_csv(dataframes[1], index_col = 0).select_dtypes(include='float64')
csv_C = pd.read_csv(dataframes[2], index_col = 0).select_dtypes(include='float64')

col_csvA = csv_A.columns
col_csvB = csv_B.columns
col_csvC = csv_C.columns

paires_col_euclidien_A_B = []
paires_col_chebyshev_A_B = []
paires_col_scalaire_A_B = []
for i in itertools.product(col_csvA, col_csvB, repeat = 1):
    col1 = csv_A[i[0]]
    col2 = csv_B[i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_A_B.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_A_B.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_A_B.append((i, scalaire))

paires_col_euclidien_A_C = []
paires_col_chebyshev_A_C = []
paires_col_scalaire_A_C = []
for i in itertools.product(col_csvA, col_csvC, repeat = 1):
    col1 = csv_A[i[0]]
    col2 = csv_C[i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_A_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_A_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_A_C.append((i, scalaire))

paires_col_euclidien_B_C = []
paires_col_chebyshev_B_C = []
paires_col_scalaire_B_C = []
for i in itertools.product(col_csvB, col_csvC, repeat = 1):
    col1 = csv_B[i[0]]
    col2 = csv_C[i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_B_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_B_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_B_C.append((i, scalaire))

print("paires_col_euclidien_A_B")
print(paires_col_euclidien_A_B)
print("paires_col_euclidien_A_C")
print(paires_col_euclidien_A_C)
print("paires_col_euclidien_B_C")
print(paires_col_euclidien_B_C)
print("///")
print("paires_col_chebyshev_A_B")
print(paires_col_chebyshev_A_B)
print("paires_col_chebyshev_A_C")
print(paires_col_chebyshev_A_C)
print("paires_col_chebyshev_B_C")
print(paires_col_chebyshev_B_C)
print("///")
print("paires_col_scalaire_A_B")
print(paires_col_scalaire_A_B)
print("paires_col_scalaire_A_C")
print(paires_col_scalaire_A_C)
print("paires_col_scalaire_B_C")
print(paires_col_scalaire_B_C)
# Out:
# paires_col_euclidien_A_B
# [(('insulin', 'insu'), 0.21448784007345065), (('Pregnancies', 'GR'), 3.7028419680446945)]
# paires_col_euclidien_A_C
# [(('weight', 'HW'), 0.8070834648169153), (('insulin', 'insalin'), 0.27767518607202957)]
# paires_col_euclidien_B_C
# [(('Glucose', 'gc'), 2.7179896559556145), (('insu', 'insalin'), 0.3532338327310837)]
# ///
# paires_col_chebyshev_A_B
# [(('insulin', 'insu'), 0.013517482009809623), (('Pregnancies', 'GR'), 0.12046755569018597)]
# paires_col_chebyshev_A_C
# [(('weight', 'HW'), 0.025890793412484348), (('insulin', 'insalin'), 0.008906395609218576)]
# paires_col_chebyshev_B_C
# [(('Glucose', 'gc'), 0.17698607590999202), (('insu', 'insalin'), 0.020157877377519506)]
# ///
# paires_col_scalaire_A_B
# [(('weight', 'GR'), -4.894015787933647), (('insulin', 'am'), -4.513424046123141), (('Pregnancies', 'BMI'), -5.757227776205205)]
# paires_col_scalaire_A_C
# ...

# %% [markdown]
# ## Exercice 2

# %%
# EXERCICE 2:
dataframes = ["./A.csv", "./B.csv", "./C.csv"]

#Creation des clusters
Cluster1 = []
Cluster1.append(pd.read_csv(dataframes[0], index_col = 0)[0:1000].select_dtypes(include='float64'))
Cluster1.append(pd.read_csv(dataframes[1], index_col = 0)[0:1000].select_dtypes(include='float64'))
Cluster1.append(pd.read_csv(dataframes[2], index_col = 0)[0:1000].select_dtypes(include='float64'))
display(Cluster1[0])

Cluster2 = []
Cluster2.append(pd.read_csv(dataframes[0], index_col = 0)[1000:2000].select_dtypes(include='float64'))
Cluster2.append(pd.read_csv(dataframes[1], index_col = 0)[1000:2000].select_dtypes(include='float64'))
Cluster2.append(pd.read_csv(dataframes[2], index_col = 0)[1000:2000].select_dtypes(include='float64'))
#display(Cluster2[0])

Cluster3 = []
Cluster3.append(pd.read_csv(dataframes[0], index_col = 0)[2000:3000].select_dtypes(include='float64'))
Cluster3.append(pd.read_csv(dataframes[1], index_col = 0)[2000:3000].select_dtypes(include='float64'))
Cluster3.append(pd.read_csv(dataframes[2], index_col = 0)[2000:3000].select_dtypes(include='float64'))
#display(Cluster3[0])
# Out:
#      weight     insulin  Pregnancies
# 0      91.2   72.006476     2.334258
# 1     281.2  112.912448     4.963979
# 2     286.3   69.121386     3.013676
# 3     173.0   80.245074     3.560229
# 4     242.9    3.077884     0.729022
# ..      ...         ...          ...
# 995   170.1  -44.518670     3.509121
# 996   175.3   67.357382    -1.848035
# 997   292.8   91.107710    -0.102098
# 998   110.1  193.503493     7.443877
# 999    90.2  -39.496395    -0.760296
#
# [1000 rows x 3 columns]

# %%
#Cluster1
import itertools
from scipy.spatial import distance

# distance euclidienne
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b)**2))

col_csv1 = Cluster1[0].columns
col_csv2 = Cluster1[1].columns
col_csv3 = Cluster1[2].columns

paires_col_euclidien_1_A_B = []
paires_col_chebyshev_1_A_B = []
paires_col_scalaire_1_A_B = []
for i in itertools.product(col_csv1, col_csv2, repeat = 1):
    col1 = Cluster1[0][i[0]]
    col2 = Cluster1[1][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_1_A_B.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_1_A_B.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_1_A_B.append((i, scalaire))
print("paires_col_euclidien_1_A_B")
print(paires_col_euclidien_1_A_B)
print("paires_col_chebyshev_1_A_B")
print(paires_col_chebyshev_1_A_B)
print("paires_col_scalaire_1_A_B")
print(paires_col_scalaire_1_A_B)

paires_col_euclidien_1_A_C = []
paires_col_chebyshev_1_A_C = []
paires_col_scalaire_1_A_C = []
for i in itertools.product(col_csv1, col_csv3, repeat = 1):
    col1 = Cluster1[0][i[0]]
    col2 = Cluster1[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_1_A_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_1_A_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_1_A_C.append((i, scalaire))
print("paires_col_euclidien_1_A_C")
print(paires_col_euclidien_1_A_C)
print("paires_col_chebyshev_1_A_C")
print(paires_col_chebyshev_1_A_C)
print("paires_col_scalaire_1_A_C")
print(paires_col_scalaire_1_A_C)

paires_col_euclidien_1_B_C = []
paires_col_chebyshev_1_B_C = []
paires_col_scalaire_1_B_C = []
for i in itertools.product(col_csv2, col_csv3, repeat = 1):
    col1 = Cluster1[1][i[0]]
    col2 = Cluster1[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_1_B_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_1_B_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_1_B_C.append((i, scalaire))
print("paires_col_euclidien_1_B_C")
print(paires_col_euclidien_1_B_C)
print("paires_col_chebyshev_1_B_C")
print(paires_col_chebyshev_1_B_C)
print("paires_col_scalaire_1_B_C")
print(paires_col_scalaire_1_B_C)
# Out:
# paires_col_euclidien_1_A_B
# [(('insulin', 'insu'), 0.12035412461728323), (('Pregnancies', 'GR'), 2.0904503636764193)]
# paires_col_chebyshev_1_A_B
# [(('insulin', 'insu'), 0.012362089570213702), (('Pregnancies', 'GR'), 0.11627182813667014)]
# paires_col_scalaire_1_A_B
# [(('weight', 'am'), -4.1302462832163584), (('weight', 'BMI'), 1.7332644677902795), (('insulin', 'Glucose'), -3.5396571174964357), (('Pregnancies', 'am'), -0.5005213063110769)]
# paires_col_euclidien_1_A_C
# [(('weight', 'HW'), 0.47049569572209865), (('insulin', 'insalin'), 0.15895615608242228)]
# paires_col_chebyshev_1_A_C
# [(('weight', 'HW'), 0.026942070297101273), (('insulin', 'insalin'), 0.008882646464394364)]
# paires_col_scalaire_1_A_C
# [(('weight', 'SkinThickness'), 2.1344328264549226), (('insulin', 'gc'), -0.7065139968901093)]
# paires_col_euclidien_1_B_C
# [(('Glucose', 'gc'), 1.5495671169054424), (('insu', 'insalin'), 0.19899202158863155)]
# paires_col_chebyshev_1_B_C
# ...

# %%
#Cluster2
import itertools
from scipy.spatial import distance

# distance euclidienne
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b)**2))

col_csv1 = Cluster2[0].columns
col_csv2 = Cluster2[1].columns
col_csv3 = Cluster2[2].columns

paires_col_euclidien_2_A_B = []
paires_col_chebyshev_2_A_B = []
paires_col_scalaire_2_A_B = []
for i in itertools.product(col_csv1, col_csv2, repeat = 1):
    col1 = Cluster2[0][i[0]]
    col2 = Cluster2[1][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_2_A_B.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_2_A_B.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_2_A_B.append((i, scalaire))
print("paires_col_euclidien_2_A_B")
print(paires_col_euclidien_2_A_B)
print("paires_col_chebyshev_2_A_B")
print(paires_col_chebyshev_2_A_B)
print("paires_col_scalaire_2_A_B")
print(paires_col_scalaire_2_A_B)

paires_col_euclidien_2_A_C = []
paires_col_chebyshev_2_A_C = []
paires_col_scalaire_2_A_C = []
for i in itertools.product(col_csv1, col_csv3, repeat = 1):
    col1 = Cluster2[0][i[0]]
    col2 = Cluster2[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_2_A_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_2_A_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_2_A_C.append((i, scalaire))
print("paires_col_euclidien_2_A_C")
print(paires_col_euclidien_2_A_C)
print("paires_col_chebyshev_2_A_C")
print(paires_col_chebyshev_2_A_C)
print("paires_col_scalaire_2_A_C")
print(paires_col_scalaire_2_A_C)

paires_col_euclidien_2_B_C = []
paires_col_chebyshev_2_B_C = []
paires_col_scalaire_2_B_C = []
for i in itertools.product(col_csv2, col_csv3, repeat = 1):
    col1 = Cluster2[1][i[0]]
    col2 = Cluster2[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_2_B_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_2_B_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_2_B_C.append((i, scalaire))
print("paires_col_euclidien_2_B_C")
print(paires_col_euclidien_2_B_C)
print("paires_col_chebyshev_2_B_C")
print(paires_col_chebyshev_2_B_C)
print("paires_col_scalaire_2_B_C")
print(paires_col_scalaire_2_B_C)
# Out:
# paires_col_euclidien_2_A_B
# [(('insulin', 'insu'), 0.12687272351660397), (('Pregnancies', 'GR'), 2.167847287615596)]
# paires_col_chebyshev_2_A_B
# [(('insulin', 'insu'), 0.012103046831888842), (('Pregnancies', 'GR'), 0.12204463402423293)]
# paires_col_scalaire_2_A_B
# [(('weight', 'GR'), -6.061456349856636), (('Pregnancies', 'Glucose'), -2.257242179911721), (('Pregnancies', 'DiabetesPedigreeFunction'), -3.199529663336083)]
# paires_col_euclidien_2_A_C
# [(('weight', 'HW'), 0.4651413756552553), (('insulin', 'insalin'), 0.16073871082670743)]
# paires_col_chebyshev_2_A_C
# [(('weight', 'HW'), 0.026175339383355478), (('insulin', 'insalin'), 0.008812188297001478)]
# paires_col_scalaire_2_A_C
# [(('insulin', 'SkinThickness'), -2.0717099553584992), (('Pregnancies', 'gc'), 0.4716505427740847)]
# paires_col_euclidien_2_B_C
# [(('Glucose', 'gc'), 1.564992141946472), (('insu', 'insalin'), 0.20577824793875388)]
# paires_col_chebyshev_2_B_C
# ...

# %%
#Cluster3
import itertools
from scipy.spatial import distance

# distance euclidienne
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b)**2))

col_csv1 = Cluster3[0].columns
col_csv2 = Cluster3[1].columns
col_csv3 = Cluster3[2].columns

paires_col_euclidien_3_A_B = []
paires_col_chebyshev_3_A_B = []
paires_col_scalaire_3_A_B = []
for i in itertools.product(col_csv1, col_csv2, repeat = 1):
    col1 = Cluster3[0][i[0]]
    col2 = Cluster3[1][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_3_A_B.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_3_A_B.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_3_A_B.append((i, scalaire))
print("paires_col_euclidien_3_A_B")
print(paires_col_euclidien_3_A_B)
print("paires_col_chebyshev_3_A_B")
print(paires_col_chebyshev_3_A_B)
print("paires_col_scalaire_3_A_B")
print(paires_col_scalaire_3_A_B)

paires_col_euclidien_3_A_C = []
paires_col_chebyshev_3_A_C = []
paires_col_scalaire_3_A_C = []
for i in itertools.product(col_csv1, col_csv3, repeat = 1):
    col1 = Cluster3[0][i[0]]
    col2 = Cluster3[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_3_A_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_3_A_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_3_A_C.append((i, scalaire))
print("paires_col_euclidien_3_A_C")
print(paires_col_euclidien_3_A_C)
print("paires_col_chebyshev_3_A_C")
print(paires_col_chebyshev_3_A_C)
print("paires_col_scalaire_3_A_C")
print(paires_col_scalaire_3_A_C)

paires_col_euclidien_3_B_C = []
paires_col_chebyshev_3_B_C = []
paires_col_scalaire_3_B_C = []
for i in itertools.product(col_csv2, col_csv3, repeat = 1):
    col1 = Cluster3[1][i[0]]
    col2 = Cluster3[2][i[1]]
    col_standard1 = (col1 - col1.mean()) / col1.std()
    col_standard2 = (col2 - col2.mean()) / col2.std()
    euclidien = euclidean_distance(col_standard1, col_standard2)
    distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
    scalaire = np.dot(col_standard1,col_standard2)
    if euclidien < 10: 
            paires_col_euclidien_3_B_C.append((i, euclidien))
    if distance_chebyshev < 1:
        paires_col_chebyshev_3_B_C.append((i, distance_chebyshev))
    if scalaire < 7 and scalaire > -7:
        paires_col_scalaire_3_B_C.append((i, scalaire))
print("paires_col_euclidien_3_B_C")
print(paires_col_euclidien_3_B_C)
print("paires_col_chebyshev_3_B_C")
print(paires_col_chebyshev_3_B_C)
print("paires_col_scalaire_3_B_C")
print(paires_col_scalaire_3_B_C)
# Out:
# paires_col_euclidien_3_A_B
# [(('insulin', 'insu'), 0.12415789199038918), (('Pregnancies', 'GR'), 2.1574361584115294)]
# paires_col_chebyshev_3_A_B
# [(('insulin', 'insu'), 0.013634755871475723), (('Pregnancies', 'GR'), 0.1233014837502675)]
# paires_col_scalaire_3_A_B
# [(('weight', 'DiabetesPedigreeFunction'), 1.0302704785018442), (('Pregnancies', 'Glucose'), -5.163366768912169), (('Pregnancies', 'insu'), -5.290106811327899), (('Pregnancies', 'BMI'), -6.4852496920149765)]
# paires_col_euclidien_3_A_C
# [(('weight', 'HW'), 0.461366787641717), (('insulin', 'insalin'), 0.16129813521731814)]
# paires_col_chebyshev_3_A_C
# [(('weight', 'HW'), 0.025923087793388477), (('insulin', 'insalin'), 0.008957416336834723)]
# paires_col_scalaire_3_A_C
# [(('insulin', 'BloodPressure'), -6.174017527727786), (('insulin', 'SkinThickness'), 4.225857264478432), (('Pregnancies', 'insalin'), -5.1649781340512675), (('Pregnancies', 'gc'), -1.7044900547670885)]
# paires_col_euclidien_3_B_C
# ...

# %%
print("RESULTAT EXERCICE 1 EUCLIDIEN")
print("paires_col_euclidien_A_B")
print(paires_col_euclidien_A_B)
print("paires_col_euclidien_A_C")
print(paires_col_euclidien_A_C)
print("paires_col_euclidien_B_C")
print(paires_col_euclidien_B_C)
print('/////')
print("RESULTAT EXERCICE 2 EUCLIDIEN")
print("paires_col_euclidien_1_A_B")
print(paires_col_euclidien_1_A_B)
print("paires_col_euclidien_2_A_B")
print(paires_col_euclidien_2_A_B)
print("paires_col_euclidien_3_A_B")
print(paires_col_euclidien_3_A_B)
print('/////')
print("paires_col_euclidien_1_A_C")
print(paires_col_euclidien_1_A_C)
print("paires_col_euclidien_2_A_C")
print(paires_col_euclidien_2_A_C)
print("paires_col_euclidien_3_A_C")
print(paires_col_euclidien_3_A_C)
print('/////')
print("paires_col_euclidien_1_B_C")
print(paires_col_euclidien_1_B_C)
print("paires_col_euclidien_2_B_C")
print(paires_col_euclidien_2_B_C)
print("paires_col_euclidien_3_B_C")
print(paires_col_euclidien_3_B_C)
# Out:
# RESULTAT EXERCICE 1 EUCLIDIEN
# paires_col_euclidien_A_B
# [(('insulin', 'insu'), 0.21448784007345065), (('Pregnancies', 'GR'), 3.7028419680446945)]
# paires_col_euclidien_A_C
# [(('weight', 'HW'), 0.8070834648169153), (('insulin', 'insalin'), 0.27767518607202957)]
# paires_col_euclidien_B_C
# [(('Glucose', 'gc'), 2.7179896559556145), (('insu', 'insalin'), 0.3532338327310837)]
# /////
# RESULTAT EXERCICE 2 EUCLIDIEN
# paires_col_euclidien_1_A_B
# [(('insulin', 'insu'), 0.12035412461728323), (('Pregnancies', 'GR'), 2.0904503636764193)]
# paires_col_euclidien_2_A_B
# [(('insulin', 'insu'), 0.12687272351660397), (('Pregnancies', 'GR'), 2.167847287615596)]
# paires_col_euclidien_3_A_B
# [(('insulin', 'insu'), 0.12415789199038918), (('Pregnancies', 'GR'), 2.1574361584115294)]
# /////
# paires_col_euclidien_1_A_C
# [(('weight', 'HW'), 0.47049569572209865), (('insulin', 'insalin'), 0.15895615608242228)]
# paires_col_euclidien_2_A_C
# ...

# %%
print("RESULTAT EXERCICE 1 CHEBYSHEV")
print("paires_col_chebyshev_A_B")
print(paires_col_chebyshev_A_B)
print("paires_col_chebyshev_A_C")
print(paires_col_chebyshev_A_C)
print("paires_col_chebyshev_B_C")
print(paires_col_chebyshev_B_C)
print('/////')
print("RESULTAT EXERCICE 2 CHEBYSHEV")
print("paires_col_chebyshev_1_A_B")
print(paires_col_chebyshev_1_A_B)
print("paires_col_chebyshev_2_A_B")
print(paires_col_chebyshev_2_A_B)
print("paires_col_chebyshev_3_A_B")
print(paires_col_chebyshev_3_A_B)
print('/////')
print("paires_col_chebyshev_1_A_C")
print(paires_col_chebyshev_1_A_C)
print("paires_col_chebyshev_2_A_C")
print(paires_col_chebyshev_2_A_C)
print("paires_col_chebyshev_3_A_C")
print(paires_col_chebyshev_3_A_C)
print('/////')
print("paires_col_chebyshev_1_B_C")
print(paires_col_chebyshev_1_B_C)
print("paires_col_chebyshev_2_B_C")
print(paires_col_chebyshev_2_B_C)
print("paires_col_chebyshev_3_B_C")
print(paires_col_chebyshev_3_B_C)
# Out:
# RESULTAT EXERCICE 1 CHEBYSHEV
# paires_col_chebyshev_A_B
# [(('insulin', 'insu'), 0.013517482009809623), (('Pregnancies', 'GR'), 0.12046755569018597)]
# paires_col_chebyshev_A_C
# [(('weight', 'HW'), 0.025890793412484348), (('insulin', 'insalin'), 0.008906395609218576)]
# paires_col_chebyshev_B_C
# [(('Glucose', 'gc'), 0.17698607590999202), (('insu', 'insalin'), 0.020157877377519506)]
# /////
# RESULTAT EXERCICE 2 CHEBYSHEV
# paires_col_chebyshev_1_A_B
# [(('insulin', 'insu'), 0.012362089570213702), (('Pregnancies', 'GR'), 0.11627182813667014)]
# paires_col_chebyshev_2_A_B
# [(('insulin', 'insu'), 0.012103046831888842), (('Pregnancies', 'GR'), 0.12204463402423293)]
# paires_col_chebyshev_3_A_B
# [(('insulin', 'insu'), 0.013634755871475723), (('Pregnancies', 'GR'), 0.1233014837502675)]
# /////
# paires_col_chebyshev_1_A_C
# [(('weight', 'HW'), 0.026942070297101273), (('insulin', 'insalin'), 0.008882646464394364)]
# paires_col_chebyshev_2_A_C
# ...

# %%
print("RESULTAT EXERCICE 1 SCALAIRE")
print("paires_col_scalaire_A_B")
print(paires_col_scalaire_A_B)
print("paires_col_scalaire_A_C")
print(paires_col_scalaire_A_C)
print("paires_col_scalaire_B_C")
print(paires_col_scalaire_B_C)
print('/////')
print("RESULTAT EXERCICE 2 SCALAIRE")
print("paires_col_scalaire_1_A_B")
print(paires_col_scalaire_1_A_B)
print("paires_col_scalaire_2_A_B")
print(paires_col_scalaire_2_A_B)
print("paires_col_scalaire_3_A_B")
print(paires_col_scalaire_3_A_B)
print('/////')
print("paires_col_scalaire_1_A_C")
print(paires_col_scalaire_1_A_C)
print("paires_col_scalaire_2_A_C")
print(paires_col_scalaire_2_A_C)
print("paires_col_scalaire_3_A_C")
print(paires_col_scalaire_3_A_C)
print('/////')
print("paires_col_scalaire_1_B_C")
print(paires_col_scalaire_1_B_C)
print("paires_col_scalaire_2_B_C")
print(paires_col_scalaire_2_B_C)
print("paires_col_scalaire_3_B_C")
print(paires_col_scalaire_3_B_C)
# Out:
# RESULTAT EXERCICE 1 SCALAIRE
# paires_col_scalaire_A_B
# [(('weight', 'GR'), -4.894015787933647), (('insulin', 'am'), -4.513424046123141), (('Pregnancies', 'BMI'), -5.757227776205205)]
# paires_col_scalaire_A_C
# [(('Pregnancies', 'SkinThickness'), 4.9479076076767115), (('Pregnancies', 'HW'), -2.649464238965887)]
# paires_col_scalaire_B_C
# [(('GR', 'SkinThickness'), 2.596980465666064), (('GR', 'HW'), -5.000882915080407), (('am', 'insalin'), -4.212260249803158), (('am', 'gc'), 6.9884209480431565)]
# /////
# RESULTAT EXERCICE 2 SCALAIRE
# paires_col_scalaire_1_A_B
# [(('weight', 'am'), -4.1302462832163584), (('weight', 'BMI'), 1.7332644677902795), (('insulin', 'Glucose'), -3.5396571174964357), (('Pregnancies', 'am'), -0.5005213063110769)]
# paires_col_scalaire_2_A_B
# [(('weight', 'GR'), -6.061456349856636), (('Pregnancies', 'Glucose'), -2.257242179911721), (('Pregnancies', 'DiabetesPedigreeFunction'), -3.199529663336083)]
# paires_col_scalaire_3_A_B
# ...

# %% [markdown]
# # Exercice 3

# %%
dataframes = ["./A.csv", "./B.csv", "./C.csv"]

csv_A_string = pd.read_csv(dataframes[0], index_col = 0).select_dtypes(include='object').fillna('')
print(csv_A_string.dtypes)
print("////")
csv_B_string = pd.read_csv(dataframes[1], index_col = 0).select_dtypes(include='object').fillna('')
print(csv_B_string.dtypes)
print("////")
csv_C_string = pd.read_csv(dataframes[2], index_col = 0).select_dtypes(include='object').fillna('')
print(csv_C_string.dtypes)
# Out:
# covid_symptoms      object
# diabete_symptoms    object
# smoking_symptoms    object
# loc                 object
# dtype: object
# ////
# wh              object
# sd              object
# medical_cat     object
# medical_size    object
# dtype: object
# ////
# cancer_symptoms    object
# MPO                object
# smplso             object
# dtype: object

# %%
import Levenshtein
 
# Fonction pour calculer la distance de Levenshtein
def calcul_levenshtein(a,b):
    return Levenshtein.distance(a, b)

col_csvA = csv_A_string.columns
col_csvB = csv_B_string.columns
col_csvC = csv_C_string.columns

paires_col_levenshtein_A_B = []
for i in itertools.product(col_csvA, col_csvB, repeat = 1):
    col1 = csv_A_string[i[0]]
    col2 = csv_B_string[i[1]]
    
    levenshtein_results = 0
    for index in range(3000):
        levenshtein_results += calcul_levenshtein(col1[index], col2[index])
        #print(levenshtein_results, col1[index],  col2[index])
        
    levenshtein_result = levenshtein_results/3000
    #printlevenshtein_result)
    
    if levenshtein_result < 7:
        paires_col_levenshtein_A_B.append((i, levenshtein_result))   
print(paires_col_levenshtein_A_B)
# Out:
# [(('diabete_symptoms', 'sd'), 4.400333333333333), (('loc', 'wh'), 4.281)]

# %%
paires_col_levenshtein_A_C = []
for i in itertools.product(col_csvA, col_csvC, repeat = 1):
    col1 = csv_A_string[i[0]]
    col2 = csv_C_string[i[1]]
    
    levenshtein_results = 0
    count = 0
    for index in range(3000):
        levenshtein_results += calcul_levenshtein(col1[index], col2[index])
        #print(levenshtein_results, col1[index],  col2[index])
        
    levenshtein_result = levenshtein_results/3000
    #printlevenshtein_result)
    if levenshtein_result < 7:
        paires_col_levenshtein_A_C.append((i, levenshtein_result))   
print(paires_col_levenshtein_A_C)
# Out:
# [(('smoking_symptoms', 'smplso'), 4.307)]

# %%
paires_col_levenshtein_B_C = []
for i in itertools.product(col_csvB, col_csvC, repeat = 1):
    col1 = csv_B_string[i[0]]
    col2 = csv_C_string[i[1]]
    
    levenshtein_results = 0
    count = 0
    for index in range(3000):
        levenshtein_results += calcul_levenshtein(col1[index], col2[index])
        #print(levenshtein_results, col1[index],  col2[index])
        
    levenshtein_result = levenshtein_results/3000
    #printlevenshtein_result)
    
    if levenshtein_result < 7:
        paires_col_levenshtein_B_C.append((i, levenshtein_result))   
print(paires_col_levenshtein_B_C)
# Out:
# []

# %%
from jellyfish import jaro_winkler_similarity

col_csvA = csv_A_string.columns
col_csvB = csv_B_string.columns
col_csvC = csv_C_string.columns

paires_col_pyjarowinkler_A_B = []
for i in itertools.product(col_csvA, col_csvB, repeat = 1):
    col1 = csv_A_string[i[0]]
    col2 = csv_B_string[i[1]]
    
    pyjarowinkler_results = 0
    for index in range(3000):
        pyjarowinkler_results += jaro_winkler_similarity(col1[index], col2[index])
        #print(pyjarowinkler_result, col1[index],  col2[index])
        
    pyjarowinkler_result = pyjarowinkler_results/3000
    #print(pyjarowinkler_result)

    if pyjarowinkler_result > 0.6:
        paires_col_pyjarowinkler_A_B.append((i, pyjarowinkler_result))
print(paires_col_pyjarowinkler_A_B)
# Out:
# [(('diabete_symptoms', 'sd'), 0.864866580791797), (('loc', 'wh'), 0.8378037807011377)]

# %%
paires_col_pyjarowinkler_A_C = []
for i in itertools.product(col_csvA, col_csvC, repeat = 1):
    col1 = csv_A_string[i[0]]
    col2 = csv_C_string[i[1]]
    
    pyjarowinkler_results = 0
    for index in range(3000):
        pyjarowinkler_results += jaro_winkler_similarity(col1[index], col2[index])
        #print(pyjarowinkler_result, col1[index],  col2[index])
        
    pyjarowinkler_result = pyjarowinkler_results/3000
    #print(pyjarowinkler_result)

    if pyjarowinkler_result > 0.6:
        paires_col_pyjarowinkler_A_C.append((i, pyjarowinkler_result))
print(paires_col_pyjarowinkler_A_C)
# Out:
# [(('diabete_symptoms', 'MPO'), 0.7506294284051789), (('smoking_symptoms', 'smplso'), 0.8498192144470241)]

# %%
paires_col_pyjarowinkler_B_C = []
for i in itertools.product(col_csvB, col_csvC, repeat = 1):
    col1 = csv_B_string[i[0]]
    col2 = csv_C_string[i[1]]
    
    pyjarowinkler_results = 0
    for index in range(3000):
        pyjarowinkler_results += jaro_winkler_similarity(col1[index], col2[index])
        #print(pyjarowinkler_result, col1[index],  col2[index])
        
    pyjarowinkler_result = pyjarowinkler_results/3000
    #print(pyjarowinkler_result)

    if pyjarowinkler_result > 0.6:
        paires_col_pyjarowinkler_B_C.append((i, pyjarowinkler_result))
print(paires_col_pyjarowinkler_B_C)
# Out:
# [(('sd', 'MPO'), 0.6762169127691507)]

# %% [markdown]
# # Exercice 4

# %% [markdown]
# # Exercice 5

# %%
dataframes = ["./A.csv", "./B.csv", "./C.csv"]

exo5_csv_A = pd.read_csv(dataframes[0], index_col = 0).fillna('')
print(csv_A.dtypes)
print("////")
exo5_csv_B = pd.read_csv(dataframes[1], index_col = 0).fillna('')
print(csv_B.dtypes)
print("////")
exo5_csv_C = pd.read_csv(dataframes[2], index_col = 0).fillna('')
print(csv_C.dtypes)
# Out:
# covid_symptoms       object
# diabete_symptoms     object
# smoking_symptoms     object
# loc                  object
# age                   int64
# weight              float64
# insulin             float64
# Pregnancies         float64
# dtype: object
# ////
# wh                           object
# sd                           object
# medical_cat                  object
# medical_size                 object
# GR                          float64
# am                          float64
# Glucose                     float64
# insu                        float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# dtype: object
# ////
# cancer_symptoms     object
# MPO                 object
# smplso              object
# BloodPressure      float64
# insalin            float64
# gc                 float64
# SkinThickness      float64
# HW                 float64
# dtype: object

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b)**2))

def similarite_structurelle_contenu(csv1, csv2):
    #return np.sqrt(np.sum((a - b)**2))
    col_csv1 = csv1.columns
    col_csv2 = csv2.columns

    paires_similarite_structurelle_jarowinkler = []
    paires_similarite_structurelle_levenshtein = []
    paires_similarite_contenu_jarowinkler = []
    paires_similarite_contenu_levenshtein = []
    paires_similarite_contenu_euclidien = []
    paires_similarite_contenu_chebyshev = []
    paires_similarite_contenu_scalaire = []
    paires_sans_similarite = []
    for i in itertools.product(col_csv1, col_csv2, repeat = 1):
        col1 = csv1[i[0]]
        col2 = csv2[i[1]]
        col1_type = col1.dtypes
        col2_type = col2.dtypes

        if col1_type != col2_type or col1_type == "int64" or col2_type == "int64":
            #print(col1_type, "!=", col2_type, "OR", col1_type, "== int64 OR",  col2_type, "== int64")
            continue

        similarite_structurelle_jarowinkler = jaro_winkler_similarity(i[0], i[1])
        if similarite_structurelle_jarowinkler > 0.7:
            paires_similarite_structurelle_jarowinkler.append((i, similarite_structurelle_jarowinkler))
            #print(similarite_structurelle_jarowinkler, "structurel jarowinkler", i)
            continue

        similarite_structurelle_levenshtein = calcul_levenshtein(i[0], i[1])
        if similarite_structurelle_levenshtein < 3:
            paires_similarite_structurelle_levenshtein.append((i, similarite_structurelle_levenshtein))
            #print(similarite_structurelle_levenshtein, "structurel levenshtein", i)
            continue
            
        #print("sans similarité structurelle", i)
        
        if col1_type == "object" and col2_type == "object":
            #print("all object")
            pyjarowinkler_results = 0
            for index in range(3000):
                pyjarowinkler_results += jaro_winkler_similarity(col1[index], col2[index])
                #print(pyjarowinkler_results, col1[index],  col2[index])
        
            pyjarowinkler_result = pyjarowinkler_results/3000
            #print(pyjarowinkler_result)
            if pyjarowinkler_result > 0.6:
                paires_similarite_contenu_jarowinkler.append((i, pyjarowinkler_result))
                continue
                
            levenshtein_results = 0
            for index in range(3000):
                levenshtein_results += calcul_levenshtein(col1[index], col2[index])
                #print(levenshtein_results, col1[index],  col2[index])

            levenshtein_result = levenshtein_results/3000
            #print(levenshtein_result)
            if levenshtein_result < 3:
                paires_similarite_contenu_levenshtein.append((i, levenshtein_result))
                continue
                
            
        if col1_type == "float64" and col2_type == "float64":
            #print("all float64")
            col_standard1 = (col1 - col1.mean()) / col1.std()
            col_standard2 = (col2 - col2.mean()) / col2.std()
            
            euclidien = euclidean_distance(col_standard1, col_standard2)
            if euclidien < 10: 
                paires_similarite_contenu_euclidien.append((i, euclidien))
                continue   
                    
            distance_chebyshev = distance.chebyshev(col_standard1, col_standard2)
            if distance_chebyshev < 1:
                paires_similarite_contenu_chebyshev.append((i, distance_chebyshev))
                continue 

            scalaire = np.dot(col_standard1,col_standard2)
            if scalaire < 7 and scalaire > -7:
                paires_similarite_contenu_scalaire.append((i, scalaire))  
                continue 
            
        paires_sans_similarite.append(i)
            
    result = {}
    result["paires_similarite_structurelle_jarowinkler"] = paires_similarite_structurelle_jarowinkler
    result["paires_similarite_structurelle_levenshtein"] = paires_similarite_structurelle_levenshtein
    result["paires_similarite_contenu_jarowinkler"] = paires_similarite_contenu_jarowinkler
    result["paires_similarite_contenu_levenshtein"] = paires_similarite_contenu_levenshtein
    result["paires_similarite_contenu_euclidien"] = paires_similarite_contenu_euclidien
    result["paires_similarite_contenu_chebyshev"] = paires_similarite_contenu_chebyshev
    result["paires_similarite_contenu_scalaire"] =  paires_similarite_contenu_scalaire
    result["paires_sans_similarite"] = paires_sans_similarite
    return result

print("--------------------------A B------------------------")
result_similarite_AB = similarite_structurelle_contenu(exo5_csv_A, exo5_csv_B)
print("//// structurelle_jarowinkler ////")
print(result_similarite_AB["paires_similarite_structurelle_jarowinkler"])
print("//// structurelle_levenshtein ////")
print(result_similarite_AB["paires_similarite_structurelle_levenshtein"])
print("//// contenu_jarowinkler ////")
print(result_similarite_AB["paires_similarite_contenu_jarowinkler"])
print("//// contenu_levenshtein ////")
print(result_similarite_AB["paires_similarite_contenu_levenshtein"])
print("//// contenu_euclidien ////")
print(result_similarite_AB["paires_similarite_contenu_euclidien"])
print("//// contenu_chebyshev ////")
print(result_similarite_AB["paires_similarite_contenu_chebyshev"])
print("//// contenu_scalaire ////")
print(result_similarite_AB["paires_similarite_contenu_scalaire"])
print("//// sans_similarite ////")
print(result_similarite_AB["paires_sans_similarite"])

print("--------------------------A C--------------------------")
result_similarite_AC = similarite_structurelle_contenu(exo5_csv_A, exo5_csv_C)
print("//// structurelle_jarowinkler ////")
print(result_similarite_AC["paires_similarite_structurelle_jarowinkler"])
print("//// structurelle_levenshtein ////")
print(result_similarite_AC["paires_similarite_structurelle_levenshtein"])
print("//// contenu_jarowinkler ////")
print(result_similarite_AC["paires_similarite_contenu_jarowinkler"])
print("//// contenu_levenshtein ////")
print(result_similarite_AC["paires_similarite_contenu_levenshtein"])
print("//// contenu_euclidien ////")
print(result_similarite_AC["paires_similarite_contenu_euclidien"])
print("//// contenu_chebyshev ////")
print(result_similarite_AC["paires_similarite_contenu_chebyshev"])
print("//// contenu_scalaire ////")
print(result_similarite_AC["paires_similarite_contenu_scalaire"])
print("//// sans_similarite ////")
print(result_similarite_AC["paires_sans_similarite"])

print("---------------------------B C-------------------------")
result_similarite_BC = similarite_structurelle_contenu(exo5_csv_B, exo5_csv_C)
print("//// structurelle_jarowinkler ////")
print(result_similarite_BC["paires_similarite_structurelle_jarowinkler"])
print("//// structurelle_levenshtein ////")
print(result_similarite_BC["paires_similarite_structurelle_levenshtein"])
print("//// contenu_jarowinkler ////")
print(result_similarite_BC["paires_similarite_contenu_jarowinkler"])
print("//// contenu_levenshtein ////")
print(result_similarite_BC["paires_similarite_contenu_levenshtein"])
print("//// contenu_euclidien ////")
print(result_similarite_BC["paires_similarite_contenu_euclidien"])
print("//// contenu_chebyshev ////")
print(result_similarite_BC["paires_similarite_contenu_chebyshev"])
print("//// contenu_scalaire ////")
print(result_similarite_BC["paires_similarite_contenu_scalaire"])
print("//// sans_similarite ////")
print(result_similarite_BC["paires_sans_similarite"])
# Out:
# --------------------------A B------------------------
# //// structurelle_jarowinkler ////
# [(('insulin', 'insu'), 0.9142857142857143)]
# //// structurelle_levenshtein ////
# []
# //// contenu_jarowinkler ////
# [(('diabete_symptoms', 'sd'), 0.864866580791797), (('loc', 'wh'), 0.8378037807011377)]
# //// contenu_levenshtein ////
# []
# //// contenu_euclidien ////
# [(('Pregnancies', 'GR'), 3.7028419680446945)]
# //// contenu_chebyshev ////
# []
# //// contenu_scalaire ////
# [(('weight', 'GR'), -4.894015787933647), (('insulin', 'am'), -4.513424046123141), (('Pregnancies', 'BMI'), -5.757227776205205)]
# //// sans_similarite ////
# ...

# %%
pip install Levenshtein

# %%
pip install pyjarowinkler

# %%
pip install jarowinkler
