# %%
import requests
import pandas as pd

# RECUPERER LES PARKINGS
url = "https://www.datasud.fr/fr/datapusher/ws/default/usergroup506.eaae7b11-d531-47c4-be6e-75b0b9b9235e/all.xlsx?maxfeatures=-1&filename=avignon-equipements-parkings" 
response = requests.get(url)
with open("avignon-equipements-parkings.xlsx", 'wb') as f:
    f.write(response.content)
df = pd.read_excel("avignon-equipements-parkings.xlsx")
print(df.head())

# RECUPERER LES STATIONNEMENTS VELOS
url = "https://www.datasud.fr/fr/datapusher/ws/default/usergroup506.911f9ba7-442f-4bfd-b720-bcb9b1b4bd3d/all.xlsx?maxfeatures=-1&filename=avignon-stationnement-pour-les-velos-arceaux" 
response = requests.get(url)
with open("avignon-stationnement-pour-les-velos-arceaux.xlsx", 'wb') as f:
    f.write(response.content)
df = pd.read_excel("avignon-stationnement-pour-les-velos-arceaux.xlsx")
print(df.head())

# RECUPERER LES STATIONNEMENTS PMR
#Necessite un bot de scrapping qui va cliquer sur le bouton de download sur la carte
bot_result = "https://umap.openstreetmap.fr/fr/map/avignon-places-de-stationnement-pmr_19410#12/43.9467/4.8338"
# response = requests.get(url)
# with open("avignon___places_de_stationnement_pmr.csv", 'wb') as f:
#     f.write(response.content)
# Out:
#      gid  id                      nom                type  ref_arrete  \
# 0  25000   1  PARKING ESPACE SCALACTA           P gratuit         NaN
# 1  25001   2   PARKING CHARLES FAVIER           P gratuit         NaN
# 2  25002   3      PARKING RUE FERRUCE  P autocars gratuit         NaN
# 3  25003   4      DEPOSE CARS BENEZET  P autocars gratuit         NaN
# 4  25004   5   PARKING DES MARAICHERS         P+R gratuit         NaN
#
#    date_arrete  type_arrete statut  annee_liste  festival_liste  ...  \
# 0          NaN          NaN     OK         True            True  ...
# 1          NaN          NaN     OK         True            True  ...
# 2          NaN          NaN     OK        False            True  ...
# 3          NaN          NaN     OK        False            True  ...
# 4          NaN          NaN     OK        False            True  ...
#
#    meta_insee  meta_siren meta_millesime   meta_datcreat meta_datsupp  \
# 0       84007   218400075           2016  20140422000000          NaN
# 1       84007   218400075           2016  20140422000000          NaN
# 2       84007   218400075           2016  20140422000000          NaN
# 3       84007   218400075           2016  20140422000000          NaN
# 4       84007   218400075           2016  20150526152000          NaN
#
#       meta_datmaj                 meta_source meta_actif                lon  \
# 0  20160317100928  Mairie Avignon/Circulation       True  4,871474489973708
# 1  20160317100928  Mairie Avignon/Circulation       True  4,871105377013629
# 2  20160317100928  Mairie Avignon/Circulation       True  4,805937645479027
# 3  20160317100928  Mairie Avignon/Circulation       True  4,803954524816514
# 4  20160317100928  Mairie Avignon/Circulation       True   4,83975457463608
#
#                  lat
# 0  43,93449969762595
# 1  43,93490936272306
# 2  43,95306422415053
# 3  43,95237612903224
# 4  43,93101784962907
#
# [5 rows x 33 columns]
#      gid  id    nature couleur  nb_places  date_realisation  observations  \
# 0  25000  27  festival    bleu          4        20171222.0           NaN
# 1  25001   4  festival    gris          1        20171102.0           NaN
# 2  25002  28  festival    bleu          4        20180315.0           NaN
# 3  25003   2  festival    gris          5        20171102.0           NaN
# 4  25004   5  festival    gris          2        20171026.0           NaN
#
#    meta_insee  meta_siren  meta_datcreat  ...  meta_datsupp  \
# 0       84007   218400075   2.017122e+13  ...           NaN
# 1       84007   218400075   2.017112e+13  ...           NaN
# 2       84007   218400075   2.018032e+13  ...           NaN
# 3       84007   218400075   2.017112e+13  ...           NaN
# 4       84007   218400075   2.017112e+13  ...           NaN
#
#                                          meta_source meta_actif  \
# 0  Mairie Avignon / Pôle Paysages Urbains / DPT A...       True
# 1  Mairie Avignon / Pôle Paysages Urbains / DPT A...       True
# 2  Mairie Avignon / Pôle Paysages Urbains / DPT A...       True
# 3  Mairie Avignon / Pôle Paysages Urbains / DPT A...       True
# 4  Mairie Avignon / Pôle Paysages Urbains / DPT A...       True
#
#    meta_resolution_spatiale  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                         meta_licence meta_observations  \
# 0  Licence ouverte / Open licence : lO / Ol (Etalab)               NaN
# 1  Licence ouverte / Open licence : lO / Ol (Etalab)               NaN
# 2  Licence ouverte / Open licence : lO / Ol (Etalab)               NaN
# 3  Licence ouverte / Open licence : lO / Ol (Etalab)               NaN
# 4  Licence ouverte / Open licence : lO / Ol (Etalab)               NaN
#
#    meta_genealogie            nom_fic                 lon                 lat
# 0              NaN  84007-veloArceaux   4,810220763597615   43,94243637652615
# 1              NaN  84007-veloArceaux  4,8125995328612445   43,94601426728984
# 2              NaN  84007-veloArceaux  4,8242673979051585  43,941646749697526
# 3              NaN  84007-veloArceaux   4,808702334796659  43,947032397481436
# 4              NaN  84007-veloArceaux   4,823035710507031   43,94910260613368
#
# [5 rows x 21 columns]
