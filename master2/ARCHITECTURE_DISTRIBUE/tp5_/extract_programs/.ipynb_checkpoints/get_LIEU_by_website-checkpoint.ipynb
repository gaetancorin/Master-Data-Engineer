# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as BS
import html
import json


# url = "https://festival-avignon.com/fr/edition-2025/programmation/par-categorie?cat=1001"

# response = requests.get(url)

# soup = BeautifulSoup(response.text, "html.parser")
# tag_categorie = soup.find("program-by-category")

# # 2. Nettoyage des champs HTML (summary, description, etc.)
# def clean_html(html_text):
#     if not html_text:
#         return ""
#     soup = BS(html_text, "html.parser")
#     return soup.get_text(separator=" ", strip=True)

# ############# GET EVENTS
# events_raw = tag_categorie.get(":events")
# events_json = html.unescape(events_raw)
# events = json.loads(events_json)
# # 3. Extraction propre events
# cleaned_events = []
# for event in events:
#     cleaned_event = {
#         "id": event.get("id"),
#         "title": event.get("title"),
#         "subtitle": html.unescape(event.get("subtitle", "")),
#         "summary": clean_html(event.get("summary", "")),
#         "description": clean_html(event.get("description", ""))
#     }
#     cleaned_events.append(cleaned_event)

# # 4. Affichage des premiers résultats
# for ev in cleaned_events[:3]:  # affiche les 3 premiers
#     print(f"🔹 {ev['title']}")
#     print(f"   Sous-titre : {ev['subtitle']}")
#     print(f"   Résumé     : {ev['summary']}")
#     print(f"   Description: {ev['description'][:200]}...")  # tronqué
#     print("—" * 50)

#############" PLACES"
url_lieu = "https://festival-avignon.com/fr/edition-2025/programmation/par-lieu"
response = requests.get(url_lieu)
soup = BeautifulSoup(response.text, "html.parser")
tag_places = soup.find("program-by-place")
raw_places = tag_places.get(":places")
decoded_places = html.unescape(raw_places)
places = json.loads(decoded_places)

data = []
for place in places:
    print({
        "id": place["id"],
        "title": place["title"],
        "slug": place["titleSlug"],
        "address": place["location"]["address"],
        "latitude": place["location"]["latitude"],
        "longitude": place["location"]["longitude"],
    })
    data.append({
        "id": place["id"],
        "title": place["title"],
        "slug": place["titleSlug"],
        "address": place["location"]["address"],
        "latitude": place["location"]["latitude"],
        "longitude": place["location"]["longitude"],
    })

df_places = pd.DataFrame(data)
print(df_places)
df_places.to_csv("lieu_lat_long.csv", index=False, encoding="utf-8")
# Out:
# 🔹 When I Saw the Sea
#    Sous-titre : Quand j'ai vu la Mer – عندما رأيت البحر
#    Résumé     : Par le chant et par la danse, trois femmes entrent en résistance contre un système qui, au Liban, soumet les travailleuses migrantes à une forme d’esclavagisme moderne.
#    Description: Sur scène, trois femmes. Elles sont éthiopiennes et libanaises. Dans un Liban en proie aux bombes, elles tentent d’échapper au système Kafala qui soumet les travailleuses migrantes à une forme d’escla...
# ——————————————————————————————————————————————————
# 🔹 Le Canard sauvage
#    Sous-titre :
#    Résumé     : Dans Un ennemi du peuple d'Henrik Ibsen (2012), Thomas Ostermeier explorait la nécessité de défendre la vérité dans une société guidée par les intérêts économiques. Le Canard Sauvage montre quant à lui à quel point une vérité absolue peut être destructrice.
#    Description: Toute vérité n’est pas bonne à dire chez les Ekdal. Du père qui se prend pour un inventeur de génie à l’aïeul qui vit dans ses souvenirs, la vie est un mensonge dans cette famille en apparence sans hi...
# ——————————————————————————————————————————————————
# 🔹 Fusées
#    Sous-titre :
#    Résumé     : Fusées entreprend de conter aux enfants comme aux adultes l’épopée de l’exploration spatiale, en la magnifiant avec les outils artisanaux du théâtre.
#    Description: C’est l’histoire de deux hommes, deux grands garçons abandonnés dans le cosmos. Coincés dans une station spatiale, Boris et Kyril ignorent quand ils pourront rentrer chez eux. L’un pleure et sombre da...
# ——————————————————————————————————————————————————
# {'id': 1167, 'title': "Cour d'honneur du palais des Papes", 'slug': 'cour-d-honneur-du-palais-des-papes', 'address': 'Place du Palais 84000 Avignon', 'latitude': 43.950612, 'longitude': 4.807351}
# {'id': 1169, 'title': "La FabricA du Festival d'Avignon", 'slug': 'la-fabrica-du-festival-d-avignon', 'address': '11 rue Paul Achard 84000 Avignon', 'latitude': 43.934772, 'longitude': 4.797077}
# {'id': 36636, 'title': 'Opéra Grand Avignon', 'slug': 'opera-grand-avignon', 'address': "place de l'Horloge 84000 Avignon", 'latitude': 43.94974, 'longitude': 4.80573}
# {'id': 36632, 'title': 'Carrière de Boulbon', 'slug': 'carriere-de-boulbon', 'address': 'Carrière de Boulbon 13150 Boulbon', 'latitude': 43.885877, 'longitude': 4.706206}
# {'id': 1171, 'title': 'Cloître des Carmes', 'slug': 'cloitre-des-carmes', 'address': 'Place des Carmes 84000 Avignon', 'latitude': 43.95094, 'longitude': 4.81294}
# {'id': 36634, 'title': 'Cloître des Célestins', 'slug': 'cloitre-des-celestins', 'address': 'place des Corps-Saints 84000 Avignon', 'latitude': 43.94393, 'longitude': 4.80776}
# {'id': 1175, 'title': 'Cour du lycée\r\nSaint-Joseph', 'slug': 'cour-du-lycee-saint-joseph', 'address': '62 rue des Lices 84000 Avignon', 'latitude': 43.94576, 'longitude': 4.81144}
# {'id': 1179, 'title': 'Gymnase du lycée Aubanel', 'slug': 'gymnase-du-lycee-aubanel', 'address': '14 rue Palapharnerie 84000 Avignon', 'latitude': 43.952393, 'longitude': 4.811959}
# {'id': 1177, 'title': 'Théâtre Benoît-XII', 'slug': 'theatre-benoit-xii', 'address': '12 rue des Teinturiers 84000 Avignon', 'latitude': 43.94509, 'longitude': 4.81299}
# {'id': 1185, 'title': "L'Autre Scène du Grand Avignon – Vedène", 'slug': 'l-autre-scene-du-grand-avignon-–-vedene', 'address': 'Avenue Pierre de Coubertin 84270 Vedène', 'latitude': 43.97919, 'longitude': 4.90862}
# {'id': 1191, 'title': 'Gymnase du lycée Mistral', 'slug': 'gymnase-du-lycee-mistral', 'address': '20 boulevard Raspail 84000 Avignon', 'latitude': 43.9455, 'longitude': 4.80206}
# {'id': 1201, 'title': 'Collection Lambert', 'slug': 'collection-lambert', 'address': '5 rue Violette 84000 Avignon', 'latitude': 43.94495, 'longitude': 4.8044}
# {'id': 1203, 'title': 'Jardin de la Vierge du lycée Saint-Joseph', 'slug': 'jardin-de-la-vierge-du-lycee-saint-joseph', 'address': '62 rue des Lices 84000 Avignon', 'latitude': 43.94555, 'longitude': 4.81086}
# {'id': 1215, 'title': 'Jardin de la rue de Mons – Maison Jean Vilar', 'slug': 'jardin-de-la-rue-de-mons-–-maison-jean-vilar', 'address': 'Rue de Mons 84000 Avignon', 'latitude': 43.94961, 'longitude': 4.80672}
# {'id': 1187, 'title': 'Chartreuse de Villeneuve lez Avignon', 'slug': 'chartreuse-de-villeneuve-lez-avignon', 'address': '58 rue de la République 30400 Villeneuve lez Avignon', 'latitude': 43.966004, 'longitude': 4.796233}
# {'id': 343550, 'title': 'Mahabharata – Bar du Festival', 'slug': 'mahabharata-–-bar-du-festival', 'address': '10 rue des Teinturiers, 84000 Avignon', 'latitude': 43.944988, 'longitude': 4.813728}
# {'id': 1239, 'title': 'Cour du château de Vacqueyras', 'slug': 'cour-du-chateau-de-vacqueyras', 'address': "Place de l'Église 84190 Vacqueyras", 'latitude': 44.13822, 'longitude': 4.98201}
# {'id': 201876, 'title': 'Théâtre de Verdure à Courthézon', 'slug': 'theatre-de-verdure-a-courthezon', 'address': 'Parc Val Seille 1 bdv Jean Vilar 84350 Courthézon', 'latitude': 44.08961, 'longitude': 4.882997}
# {'id': 331488, 'title': 'Site archéologique de Glanum à Saint-Rémy-de-Provence', 'slug': 'site-archeologique-de-glanum-a-saint-remy-de-provence', 'address': 'Av. Vincent Van Gogh, 13210 Saint-Rémy-de-Provence', 'latitude': 43.7736, 'longitude': 4.833}
# {'id': 1231, 'title': 'Salle des fêtes La Pastourelle à Saint-Saturnin-lès-Avignon', 'slug': 'salle-des-fetes-la-pastourelle-a-saint-saturnin-les-avignon', 'address': 'Avenue du Général de Gaulle 84450 Saint-Saturnin-lès-Avignon', 'latitude': 43.95681, 'longitude': 4.92895}
# {'id': 1229, 'title': 'Complexe sportif Jean Galia à Rochefort-du-Gard', 'slug': 'complexe-sportif-jean-galia-a-rochefort-du-gard', 'address': '1 avenue du Languedoc 30650 Rochefort-du-Gard', 'latitude': 43.979337, 'longitude': 4.684165}
# {'id': 1253, 'title': 'Espace Baron de Chabert à Barbentane', 'slug': 'espace-baron-de-chabert-a-barbentane', 'address': 'Rue du château 13570 Barbentane', 'latitude': 43.900195, 'longitude': 4.746978}
# {'id': 331489, 'title': 'Les Arènes de Vallabrègues', 'slug': 'les-arenes-de-vallabregues', 'address': '30300 Vallabrègues', 'latitude': 43.854103, 'longitude': 4.628512}
# {'id': 1241, 'title': 'Salle Roger Orlando à Caumont-sur-Durance', 'slug': 'salle-roger-orlando-a-caumont-sur-durance', 'address': 'Place du Marché 84510 Caumont-sur-Durance', 'latitude': 43.89352, 'longitude': 4.94813}
# {'id': 60849, 'title': 'Cour du Château d’Aramon', 'slug': 'cour-du-chateau-d-aramon', 'address': '12 rue des Cardinaux, 30390 Aramon', 'latitude': 43.890665, 'longitude': 4.681412}
# {'id': 200865, 'title': 'Salle des fêtes de L’Isle-sur-la-Sorgue', 'slug': 'salle-des-fetes-de-l-isle-sur-la-sorgue', 'address': "1 Avenue Napoléon Bonaparte, 84800 L'Isle-sur-la-Sorgue", 'latitude': 43.923914, 'longitude': 5.052738}
# {'id': 1251, 'title': 'Cour du château de Saze', 'slug': 'cour-du-chateau-de-saze', 'address': '4 Place de la Fontaine 30650 Saze', 'latitude': 43.941111, 'longitude': 4.681667}
# {'id': 351887, 'title': 'Bibliothèque du Puzzle', 'slug': 'bibliotheque-du-puzzle', 'address': '4, rue Pierre-Auguste Renoir', 'latitude': 43.948341, 'longitude': 4.85181}
# {'id': 351885, 'title': 'Bibliothèque Renaud Barrault', 'slug': 'bibliotheque-renaud-barrault', 'address': '6 Rue Perrin Morel, 84000 Avignon, France', 'latitude': 43.929993, 'longitude': 4.822993}
# {'id': 36791, 'title': 'Festival Villeneuve en Scène', 'slug': 'festival-villeneuve-en-scene', 'address': "Plaine de l'Abbaye, 30400 Villeneuve-lès-Avignon", 'latitude': 43.96445, 'longitude': 4.802611}
# {'id': 348672, 'title': 'Forum des Angles, salle Blanchard', 'slug': 'forum-des-angles-salle-blanchard', 'address': '10 Bd des Carrières, 30133 Les Angles', 'latitude': 43.960157, 'longitude': 4.767635}
# {'id': 1193, 'title': "Les Hivernales – CDCN d'Avignon", 'slug': 'les-hivernales-–-cdcn-d-avignon', 'address': '18 rue Guillaume Puy 84000 Avignon', 'latitude': 43.9496, 'longitude': 4.8142700000000005}
# {'id': 36782, 'title': 'Médiathèque Ceccano', 'slug': 'mediatheque-ceccano', 'address': '2 bis, rue Laboureur - Avignon', 'latitude': 43.946003, 'longitude': 4.80687}
# {'id': 351166, 'title': 'Salle des colloques – Cloître Saint-Louis', 'slug': 'salle-des-colloques-–-cloitre-saint-louis', 'address': '20 rue du portail Boquier 84000 Avignon', 'latitude': 43.943603, 'longitude': 4.804582}
# {'id': 348671, 'title': 'Salle polyvalente de Pujaut', 'slug': 'salle-polyvalente-de-pujaut', 'address': '1 Place du Marché, 30131 Pujaut', 'latitude': 44.002895, 'longitude': 4.774796}
# {'id': 352026, 'title': 'Villa Créative – Avignon Université', 'slug': 'villa-creative-–-avignon-universite', 'address': '33 bis Rue Louis Pasteur, 84000 Avignon', 'latitude': 43.949848, 'longitude': 4.816221}
#         id                                              title  \
# 0     1167                 Cour d'honneur du palais des Papes
# 1     1169                   La FabricA du Festival d'Avignon
# 2    36636                                Opéra Grand Avignon
# 3    36632                                Carrière de Boulbon
# 4     1171                                 Cloître des Carmes
# 5    36634                              Cloître des Célestins
